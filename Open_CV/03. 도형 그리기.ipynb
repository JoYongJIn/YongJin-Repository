# %% [markdown]
# # 3. 도형 그리기

# %% [markdown]
# ## 빈 스케치북 만들기

# %%
import cv2
import numpy as np

#세로 480 x 가로 640, 3 Channel (RGB) 에 해당하는 스케치북 만들기
img = np.zeros((480, 640, 3), dtype=np.uint8) # 0으로 꽉찬 데이터 즉 검정색으로 꽉찬 그림이 나온다.
# img[:] = (255, 255, 255) #전체 공간을 흰 색으로 채우기 (색상 비율 변화시킴으로써 색결정짓는다.)
# print(img) #내가보기에 이미지가 화소하나하나로 이루어져 있는데 그 화소들의 값이 전부 출력된것이다.(맞다.)
cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
'''
uint8은 "unsigned integer 8 bits"의 줄임말로, 0부터 255까지의 값을 가질 수 있는 8비트 무부호 정수를 의미합니다.
이미지 데이터에서는 픽셀의 강도를 표현하는 데 주로 사용되며, 이는 각 색상 채널이 0부터 255의 값을 가질 수 있음을 의미합니다.
'''

# %% [markdown]
# ## 일부 영역 색칠

# %%
import cv2
import numpy as np


img = np.zeros((480, 640, 3), dtype=np.uint8)
img[100:200, 200:300] = (255, 255, 255)
# [세로 영역, 가로 영역]
# print(img)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 직선
# 직선의 종류 (line type)
#
# 1. cv2.LINE_4 : 상하좌우 4 방향으로 연결된 선
# 1. cv2.LINE_8 : 대각선을 포함한 8방향으로 연결된 선(기본값)
# 1. cv2.LINE_AA : 부드러운 선 (anti-aliasing)

# %%
import cv2
import numpy as np


img = np.zeros((480, 640, 3), dtype=np.uint8)

COLOR = (0, 255, 255) # BGR : Yellow 색깔
THICKNESS = 3 # 두께

cv2.line(img, (50, 100),(400, 50), COLOR, THICKNESS, cv2.LINE_8)
# 그릴 위치, 시작 점, 끝 점, 색깔, 두께, 선 종류
cv2.line(img, (50, 200),(400, 150), COLOR, THICKNESS, cv2.LINE_4)
cv2.line(img, (50, 300),(400, 250), COLOR, THICKNESS, cv2.LINE_AA)

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 원

# %%
import cv2
import numpy as np


img = np.zeros((480, 640, 3), dtype=np.uint8)

COLOR = (255, 255, 0) # BGR : 옥색
RADIUS = 50 #반지름
THICKNESS = 10 # 두께

cv2.circle(img, (200, 100), RADIUS, COLOR, THICKNESS, cv2.LINE_AA) # 속이 빈 원, THICKNESS안쓰면 기본값 1
# 그릴 위치, 원의 중심정, 반지름, 색깔, 두께, 선 종류
cv2.circle(img, (400, 100), RADIUS, COLOR, cv2.FILLED, cv2.LINE_AA) # 속이 찬 원, FILLED = -1과 같다

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 사각형

# %%
import cv2
import numpy as np


img = np.zeros((480, 640, 3), dtype=np.uint8)

COLOR = (0, 255, 0) # BGR : 초록색
THICKNESS = 3 # 두께

cv2.rectangle(img, (100,100), (200,200), COLOR, THICKNESS) # 속이 빈 사각형
# 그릴 위치, 왼쪽 위 좌표, 오른쪽 아래 좌표, 색깔, 두께
cv2.rectangle(img, (300,100), (400,300), COLOR, cv2.FILLED) # 꽉 찬 사각형

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## 다각형

# %%
import cv2
import numpy as np


img = np.zeros((480, 640, 3), dtype=np.uint8)

COLOR = (0, 0, 255) # BGR : 빨간색
THICKNESS = 3 # 두께

pts1 = np.array([[100, 100], [200, 100], [100, 200]]) # 세개의 지점을 만들고(삼각형) 리스트([])로 감싼것이다.
pts2 = np.array([[200, 100], [300, 100], [300, 200]])

# cv2.polylines(img, [pts1], True , COLOR, THICKNESS, cv2.LINE_AA) # pts1 대괄호안에 리스트로 넣어야한다. True=닫힌도형, False=열린도형
# cv2.polylines(img, [pts2], True , COLOR, THICKNESS, cv2.LINE_AA) # pts1 대괄호안에 리스트로 넣어야한다. True=닫힌도형, False=열린도형
cv2.polylines(img, [pts1, pts2], True , COLOR, THICKNESS, cv2.LINE_AA) # 리스트 안에 동시에 여러다각형 집어넣어서 그릴수있다.
# 그릴 위치, 그릴 좌표들, 닫힘 여부, 색깔, 두께, 선 종류

pts3 = np.array([[[100, 300], [200, 300], [100, 400]], [[200, 300], [300, 300], [300, 400]]]) # 위와 다르게 한번에 삼각형 두개 한리스트에 좌표넣어 그리기
cv2.fillPoly(img, pts3, COLOR, cv2.LINE_AA) # 꽉 찬 다각형
#그릴 위치, 그릴 좌표들, 색깔, 선 종류

cv2.imshow('img', img)
cv2.waitKey(0)
cv2.destroyAllWindows()
