# %% [markdown]
# <a href="https://colab.research.google.com/github/JoYongJIn/YongJin-Repository/blob/main/%08machine.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def draw_lottery():
    number = random.randint(1, 125)
    if number == 1:
        return True
    else:
        return False

def machine():
  i = 0
  a = 0, b = 0, c = 0, d = 0, e = 0, f = 0, g = 0
  while True :
    if 0=<i<41 :
      a+=1, i+=1, profit = 100*110
      break
    elif 40<i<61 :
      b+=1, i+=1, profit = 200*110
    elif 60<i<71 :
      c+=1, i+=1, profit = 300*110
    elif 70<i<81 :
      d+=1, i+=1, profit = 400*110
    elif 80<i<121 :
      e+=1, i+=1, profit = 200*110
    elif 120<i<171 :
      f+=1, i+=1, profit = 100*110
    else 170<i :
      g+=1, i+=1, profit = 10*110
    return a, b, c, d, e, f, g, i, profit


expenditure = 100*a + 200*b + 300*c + 400*d +200*e + 100*f + 10*g

net_profit = profit - expenditure

print(f"{i}번 만에 당첨되었습니다.")
print(f"순수익은 {net_profit}입니다.")
# Out:
#   File "<ipython-input-1-11d9eae666a0>", line 10
#     a = 0, b = 0, c = 0, d = 0, e = 0, f = 0, g = 0
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
import random

def draw_lottery():
    number = random.randint(1, 125)
    if number == 1:
        return True
    else:
        return False

def machine():
    i = 0
    a, b, c, d, e, f, g = 0, 0, 0, 0, 0, 0, 0
    profit = 0

    while True:
        if 0 <= i < 41:
            a += 1
            i += 1
            profit = 100 * 110
        elif 40 < i < 61:
            b += 1
            i += 1
            profit = 200 * 110
        elif 60 < i < 71:
            c += 1
            i += 1
            profit = 300 * 110
        elif 70 < i < 81:
            d += 1
            i += 1
            profit = 400 * 110
        elif 80 < i < 121:
            e += 1
            i += 1
            profit = 200 * 110
        elif 120 < i < 171:
            f += 1
            i += 1
            profit = 100 * 110
        else:
            g += 1
            i += 1
            profit = 10 * 110
        return a, b, c, d, e, f, g, i, profit

a, b, c, d, e, f, g, i, profit = machine()
expenditure = 100*a + 200*b + 300*c + 400*d +200*e + 100*f + 10*g
net_profit = profit - expenditure

print(f"{i}번 만에 당첨되었습니다.")
print(f"순수익은 {net_profit}입니다.")
# Out:
# 1번 만에 당첨되었습니다.
# 순수익은 10900입니다.

# %%
import random

def draw_lottery():
    number = random.randint(1, 125)
    if number == 1:
        return True
    else:
        return False

def machine():
    i = 0
    a, b, c, d, e, f, g = 0, 0, 0, 0, 0, 0, 0
    profit = 0

    while not draw_lottery():
        if 0 <= i < 40:
            a += 1
            profit = 100 * 110
        elif 39 < i < 60:
            b += 1
            profit = 200 * 110
        elif 59 < i < 70:
            c += 1
            profit = 300 * 110
        elif 69 < i < 80:
            d += 1
            profit = 400 * 110
        elif 79 < i < 120:
            e += 1
            profit = 200 * 110
        elif 119 < i < 170:
            f += 1
            profit = 100 * 110
        elif 169 < i :
            g += 1
            profit = 10 * 110
        i += 1

    return a, b, c, d, e, f, g, i, profit

a, b, c, d, e, f, g, i, profit = machine()
expenditure = 100*a + 200*b + 300*c + 400*d + 200*e + 100*f + 10*g
net_profit = profit - expenditure

print(f"{i}번 만에 당첨되었습니다.")
print(f"수익은 {profit}, 지출은 {-expenditure}, 순수익은 {net_profit}입니다.")
print(f"a={a} b={b} c={c} d={d} e={e} f={f} g={g}")
# Out:
# 23번 만에 당첨되었습니다.
# 수익은 11000, 지출은 -2300, 순수익은 8700입니다.
# a=23 b=0 c=0 d=0 e=0 f=0 g=0

# %%
import random

def draw_lotto():
    return random.randint(1, 125) == 1  # 1/100의 확률로 True를 반환합니다.

def main():
    total_draws = 0
    wins = 0

    while True:
        input("\n")
        total_draws += 1

        if draw_lotto():
            wins += 1
            print(f"잭팟!")
        else:
            print(f"현재까지 총 {total_draws}회 추첨하셨습니다.")

if __name__ == "__main__":
    main()

# %%
import random

def draw_lottery():
    number = random.randint(1, 125)
    if number == 1:
        return True
    else:
        return False

def machine():
    i = 0
    a, b, c, d, e, f, g = 0, 0, 0, 0, 0, 0, 0
    profit = 0

    while not draw_lottery():
        if 0 <= i < 40:
            a += 1
            profit = 100 * 110
        elif 39 < i < 60:
            b += 1
            profit = 200 * 110
        elif 59 < i < 70:
            c += 1
            profit = 300 * 110
        elif 69 < i < 80:
            d += 1
            profit = 400 * 110
        elif 79 < i < 120:
            e += 1
            profit = 200 * 110
        elif 119 < i < 170:
            f += 1
            profit = 100 * 110
        elif 169 < i :
            g += 1
            profit = 10 * 110
        i += 1

    return a, b, c, d, e, f, g, i, profit

a, b, c, d, e, f, g, i, profit = machine()
expenditure = 100*a + 200*b + 300*c + 400*d + 200*e + 100*f + 10*g
net_profit = profit - expenditure

print(f"{i}번 만에 당첨되었습니다.")
print(f"수익은 {profit}, 지출은 {-expenditure}, 순수익은 {net_profit}입니다.")
print(f"a={a} b={b} c={c} d={d} e={e} f={f} g={g}")
print(f'반환율은 {profit/expenditure*100:.2f}% 입니다.')
# Out:
# 139번 만에 당첨되었습니다.
# 수익은 11000, 지출은 -24900, 순수익은 -13900입니다.
# a=40 b=20 c=10 d=10 e=40 f=19 g=0
# 반환율은 44.18% 입니다.

# %%
import random

def draw_lottery():
    number = random.randint(1, 125)
    if number == 1:
        return True
    else:
        return False

def machine():
    i = 0
    a, b, c, d, e, f, g = 0, 0, 0, 0, 0, 0, 0
    profit = 0

    while not draw_lottery():
        input("\n")
        if 0 <= i < 40:
            a += 1
            profit = 100 * 110
        elif 39 < i < 60:
            b += 1
            profit = 200 * 110
        elif 59 < i < 70:
            c += 1
            profit = 300 * 110
        elif 69 < i < 80:
            d += 1
            profit = 400 * 110
        elif 79 < i < 120:
            e += 1
            profit = 200 * 110
        elif 119 < i < 170:
            f += 1
            profit = 100 * 110
        elif 169 < i :
            g += 1
            profit = 10 * 110
        i += 1

    return a, b, c, d, e, f, g, i, profit

if __name__ == "__machine__":
  a, b, c, d, e, f, g, i, profit = machine()
expenditure = 100*a + 200*b + 300*c + 400*d + 200*e + 100*f + 10*g
net_profit = profit - expenditure

print(f"{i}번 만에 당첨되었습니다.")
print(f"수익은 {profit}, 지출은 {-expenditure}, 순수익은 {net_profit}입니다.")
print(f"a={a} b={b} c={c} d={d} e={e} f={f} g={g}")
print(f'반환율은 {profit/expenditure*100:.2f}% 입니다.')
# Out:
# 9번 만에 당첨되었습니다.
# 수익은 11000, 지출은 -900, 순수익은 10100입니다.
# a=9 b=0 c=0 d=0 e=0 f=0 g=0
# 반환율은 1222.22% 입니다.

# %%
import random

total_profit = []
total_expenditure = []

for k in range(0,100):
    def draw_lottery():
        number = random.randint(1, 125)
        if number == 1:
            return True
        else:
            return False

    def machine():
        i = 0
        a, b, c, d, e, f, g = 0, 0, 0, 0, 0, 0, 0
        profit = 0

        while not draw_lottery():
            if 0 <= i < 40:
                a += 1
                profit = 100 * 110
            elif 39 < i < 60:
                b += 1
                profit = 200 * 110
            elif 59 < i < 70:
                c += 1
                profit = 300 * 110
            elif 69 < i < 80:
                d += 1
                profit = 400 * 110
            elif 79 < i < 120:
                e += 1
                profit = 200 * 110
            elif 119 < i < 170:
                f += 1
                profit = 100 * 110
            elif 169 < i :
                g += 1
                profit = 10 * 110
            i += 1

        return a, b, c, d, e, f, g, i, profit

    a, b, c, d, e, f, g, i, profit = machine()
    expenditure = 100*a + 200*b + 300*c + 400*d + 200*e + 100*f + 10*g
    net_profit = profit - expenditure
    total_profit.append(profit)
    total_expenditure.append(expenditure)

    #print(f"{i}번 만에 당첨되었습니다.")
    #print(f"수익은 {profit}, 지출은 {-expenditure}, 순수익은 {net_profit}입니다.")
    #print(f"a={a} b={b} c={c} d={d} e={e} f={f} g={g}")
    #print(f'반환율은 {profit/expenditure*100:.2f}% 입니다.')

#print(total_profit)
#print(total_expenditure)
print(sum(total_profit)/sum(total_expenditure))
# Out:
# 0.9711866263670402

# %%
import random

for m in range(0,10): # 숫자조합 만들어서 실험한 횟수
    # 6개의 서로 다른 난수 생성
    numbers = random.sample(range(1, 131), 6)  # 1부터 130까지의 난수 중에서 6개 선택

    numbers.sort() # 숫자들을 오름차순으로 정렬

    k1, k2, k3, k4, k5, k6 = numbers # 변수에 숫자 배정
    def make_numbers():

        total_profit = []
        total_expenditure = []

        for k in range(0,40): # 이 횟수가 잭팟이 당첨될때까지 게임하는 횟수다
            def draw_lottery():
                number = random.randint(1, 125)
                if number == 1:
                    return True
                else:
                    return False

            def machine():
                i = 0
                a, b, c, d, e, f, g = 0, 0, 0, 0, 0, 0, 0
                profit = 0
                while not draw_lottery():
                    if 0 <= i < k1:
                        a += 1
                        profit = 500 * 110
                    elif k1-1 < i < k2:
                        b += 1
                        profit = 1000 * 110
                    elif k2-1 < i < k3:
                        c += 1
                        profit = 500 * 110
                    elif k3-1 < i < k4:
                        d += 1
                        profit = 2000 * 110
                    elif k4-1 < i < k5:
                        e += 1
                        profit = 500 * 110
                    elif k5-1 < i < k6:
                        f += 1
                        profit = 10 * 110
                    elif k6-1 < i :
                        g += 1
                        profit = 10 * 110
                    i += 1

                return a, b, c, d, e, f, g, i, profit

            a, b, c, d, e, f, g, i, profit = machine()
            expenditure = 500*a + 1000*b + 500*c + 2000*d + 500*e + 10*f + 10*g
            net_profit = profit - expenditure
            total_profit.append(profit)
            total_expenditure.append(expenditure)
            #print('<compare>')
            #print(f"{i}번 만에 당첨되었습니다.")
            #print(f"수익은 {profit}, 지출은 {-expenditure}, 순수익은 {net_profit}입니다.")
            #print(f"a={a} b={b} c={c} d={d} e={e} f={f} g={g}")
            #print(f'반환율은 {profit/expenditure*100:.2f}% 입니다.')
            #print("\n")
        return k1, k2, k3, k4, k5, k6
     k1, k2, k3, k4, k5, k6 = make_numbers()

#print(total_profit)
#print(total_expenditure)
print(f"누적순수익(compare) {sum(total_profit)-sum(total_expenditure)}")
#print(f"누적반환(compare) {sum(total_profit)/sum(total_expenditure)*100:.2f}%")

#print("k1:", k1, "k2:", k2, "k3:", k3, "k4:", k4, "k5:", k5, "k6:", k6)

# %%
# 한번씩 실재라고 생각하고 바꿔가며 수익보자(한판에 8분)
import random
total_net_profit = 0
w,l = 0,0
games = 0
while True:
    s = input("어떤 전략을 택하시겠습니까?")
    if s == '1':
        k1, k2, k3, k4, k5, k6 = 50, 50, 100, 100, 50, 50
    elif s == '2':
        k1, k2, k3, k4, k5, k6 = 50, 100, 200, 300, 200, 100
    elif s == '3': #강력(model2임)
        k1, k2, k3, k4, k5, k6 = 100, 200, 300, 500, 200, 100
    elif s == '4':
        k1, k2, k3, k4, k5, k6 = 10, 10, 50, 100, 10, 10
    for k in range(0,1): # 이 횟수가 잭팟이 당첨될때까지 게임하는 횟수다(보통 40번)
        def draw_lottery():
            number = random.randint(1, 125)
            if number == 1:
                return True
            else:
                return False
        def machine():
            i = 0
            a, b, c, d, e, f, g = 0, 0, 0, 0, 0, 0, 0
            profit = 0
            while not draw_lottery():
                if 0 <= i < 20:
                    a += 1
                    profit = k1 * 110
                elif 19 < i < 40:
                    b += 1
                    profit = k2 * 110
                elif 39 < i < 63:
                    c += 1
                    profit = k3 * 110
                elif 62 < i < 75:
                    d += 1
                    profit = k4 * 110
                elif 74 < i < 108:
                    e += 1
                    profit = k5 * 110
                elif 107 < i < 130:
                    f += 1
                    profit = k6 * 110
                elif 129 < i :
                    g += 1
                    profit = 10 * 110
                i += 1
            expenditure = k1*a + k2*b + k3*c + k4*d + k5*e + k6*f + 10*g # 배팅 바꾸기
            net_profit = profit - expenditure
            print(f"{i}번 만에 당첨되었습니다.")
            print(f"수익은 {profit}, 지출은 {-expenditure}, 순수익은 {net_profit}입니다.")
            return  net_profit, i
        net_profit, i = machine()
    if i < 130:
        w += 1
    else:
        l += 1
    total_net_profit += net_profit
    games += 1
    print(f"현재 {games}판 진행중이며 누적순수익은 {total_net_profit}입니다. W:{w} L:{l}")
    print("\n")
# Out:
# 어떤 전략을 택하시겠습니까?3
# 190번 만에 당첨되었습니다.
# 수익은 1100, 지출은 -28300, 순수익은 -27200입니다.
# 현재 1판 진행중이며 누적순수익은 -27200입니다. W:0 L:1
#
#
# 어떤 전략을 택하시겠습니까?2
# 29번 만에 당첨되었습니다.
# 수익은 11000, 지출은 -1900, 순수익은 9100입니다.
# 현재 2판 진행중이며 누적순수익은 -18100입니다. W:1 L:1
#
#
# 어떤 전략을 택하시겠습니까?3
# 29번 만에 당첨되었습니다.
# 수익은 22000, 지출은 -3800, 순수익은 18200입니다.
# 현재 3판 진행중이며 누적순수익은 100입니다. W:2 L:1
#
#
# 어떤 전략을 택하시겠습니까?3
# 79번 만에 당첨되었습니다.
# 수익은 22000, 지출은 -19700, 순수익은 2300입니다.
# 현재 4판 진행중이며 누적순수익은 2400입니다. W:3 L:1
#
#
# 어떤 전략을 택하시겠습니까?
# 어떤 전략을 택하시겠습니까?
# 65번 만에 당첨되었습니다.
# 수익은 55000, 지출은 -13900, 순수익은 41100입니다.
# 현재 5판 진행중이며 누적순수익은 43500입니다. W:4 L:1
#
#
# 97번 만에 당첨되었습니다.
# 수익은 22000, 지출은 -23300, 순수익은 -1300입니다.
# 현재 6판 진행중이며 누적순수익은 42200입니다. W:5 L:1
#
#
# 어떤 전략을 택하시겠습니까?3
# 576번 만에 당첨되었습니다.
# 수익은 1100, 지출은 -32160, 순수익은 -31060입니다.
# 현재 7판 진행중이며 누적순수익은 11140입니다. W:5 L:2
