# %%
import math
import random

def generate_data(num_trials):
    trials = []
    for _ in range(num_trials):
        count = 0
        while True:
            count += 1
            if random.randint(1, 125) == 1:
                break
        trials.append(count)
    return trials

x_data = generate_data(200)

def apply_formula(x):
    y = round(1-math.exp(-x/125),4)
    return y

def generate_y_list(x_list):
    y_list = []
    for x in x_list:
        y = apply_formula(x)
        y_list.append(y)
    return y_list

# Y 데이터 리스트 생성
y_data = generate_y_list(x_data)

print("X 데이터:", x_data)
#print("Y 데이터:", y_data)
# Out:
# X 데이터: [76, 54, 34, 29, 81, 40, 492, 222, 265, 182, 105, 6, 35, 524, 116, 329, 31, 99, 49, 78, 241, 96, 355, 87, 67, 184, 335, 435, 160, 318, 520, 143, 25, 10, 64, 23, 7, 91, 34, 713, 8, 33, 146, 32, 9, 216, 9, 118, 184, 258, 91, 35, 21, 31, 44, 49, 83, 35, 138, 83, 63, 317, 35, 20, 25, 150, 5, 47, 212, 43, 8, 32, 175, 22, 39, 83, 683, 63, 511, 89, 11, 82, 164, 554, 183, 121, 168, 48, 186, 329, 34, 267, 338, 39, 51, 16, 46, 81, 32, 228, 49, 149, 94, 142, 177, 98, 60, 53, 140, 29, 103, 55, 177, 1, 90, 154, 178, 24, 40, 85, 18, 14, 152, 57, 23, 49, 181, 156, 117, 21, 103, 17, 57, 192, 12, 19, 50, 35, 175, 36, 360, 134, 23, 84, 98, 20, 4, 210, 125, 93, 131, 277, 162, 14, 9, 152, 193, 72, 111, 178, 105, 18, 131, 46, 38, 8, 98, 106, 114, 14, 157, 306, 289, 3, 92, 502, 86, 71, 141, 6, 391, 44, 181, 1, 16, 5, 198, 5, 30, 10, 111, 310, 119, 155, 343, 130, 274, 82, 208, 412]

# %% [markdown]
# # LSTM 이용시도
# 10개씩 쪼개어서 그다음 나오는 숫자를 타겟으로 하여 학습시키는 것도 가능할것같다. 근데 이렇게하면 10개가 채워지기 전에는 예측을 해주지 못한다. 하지만 10개가 넘어가고 부터는 계속 예측가능하다.

# %% [markdown]
# ### 시행횟수를 줄여 데이터의 크기를 작게하여 확인을 해보았는데 스탭크기가 8이면 처음부터 8개를 X로해서 y(lable)은 9번째수로 하여 맞게 데이터 세트가 만들어진다. lable값이 데이터세트 리스트의 맨 마지막 숫자가 되었을때 실행을 마친다.

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
import numpy as np

# 데이터셋 생성 함수
def create_dataset(numbers, n_steps):
    X, y = [], []
    for i in range(len(numbers)):
        end_ix = i + n_steps
        if end_ix > len(numbers)-1:
            break
        seq_x, seq_y = numbers[i:end_ix], numbers[end_ix] # end_ix는 포함되지 않는다.
        X.append(seq_x)
        y.append(seq_y)
    return np.array(X), np.array(y)

# 숫자 시퀀스 정의
numbers = x_data
n_steps = 20 # 학습하고싶은 숫자묶음의 크기(발걸음)을 설정합니다.

# 데이터셋 생성
X, y = create_dataset(numbers, n_steps) #데이터셋 생성 함수 활성화

print(X)
#print(y)
# Out:
# [[ 76  54  34 ...  99  49  78]
#  [ 54  34  29 ...  49  78 241]
#  [ 34  29  81 ...  78 241  96]
#  ...
#  [ 71 141   6 ... 343 130 274]
#  [141   6 391 ... 130 274  82]
#  [  6 391  44 ... 274  82 208]]

# %%
# LSTM 모델 정의
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.callbacks import EarlyStopping

model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(n_steps, 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# 모델 훈련을 위해 X를 재구성
X = X.reshape((X.shape[0], X.shape[1], 1))

# 조기 종료 콜백 설정
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# 모델 훈련
model.fit(X, y, epochs=2000, verbose=1, callbacks=[early_stopping]) # 일부러 에포크를 매우 크게 하였습니다.
# Out:
# Epoch 1/2000
# 1/6 [====>.........................] - ETA: 2s - loss: 54444.8438WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 1s 5ms/step - loss: 35978.5039
# Epoch 2/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 48615.2266WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 33395.8633
# Epoch 3/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 35315.7383WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 30486.8828
# Epoch 4/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 38876.7578WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 27645.6777
# Epoch 5/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 9782.0166WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23442.5137
# Epoch 6/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 39361.4766WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23686.9805
# Epoch 7/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18370.1172WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23184.1309
# Epoch 8/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18409.9434WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23364.5527
# Epoch 9/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16068.5049WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23100.6758
# Epoch 10/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10829.3770WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22351.3867
# Epoch 11/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 19274.6797WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21679.1367
# Epoch 12/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 33625.2422WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20894.3945
# Epoch 13/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22831.1348WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20452.7246
# Epoch 14/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12308.8730WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20373.4688
# Epoch 15/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18537.9023WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20392.2402
# Epoch 16/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16540.1934WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21324.3340
# Epoch 17/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20264.0547WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21265.7188
# Epoch 18/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 24671.0000WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21334.9707
# Epoch 19/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10480.0605WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21153.5820
# Epoch 20/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 25247.7246WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20961.3047
# Epoch 21/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17892.9023WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20550.0273
# Epoch 22/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 28180.6406WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19974.5215
# Epoch 23/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18342.9570WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19523.8672
# Epoch 24/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 19238.5508WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19498.7422
# Epoch 25/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 26914.0469WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19486.3672
# Epoch 26/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 24176.3125WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 18747.2012
# Epoch 27/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21136.6777WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 18353.2090
# Epoch 28/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 28410.1328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 18059.3477
# Epoch 29/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 9157.0332WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17485.1543
# Epoch 30/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 19162.2031WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17281.3809
# Epoch 31/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11673.9219WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17330.7422
# Epoch 32/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 13418.8574WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 16774.8633
# Epoch 33/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 9810.4004WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17188.9531
# Epoch 34/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 26112.5859WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 16371.3916
# Epoch 35/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10839.9189WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 16549.6191
# Epoch 36/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 6509.2666WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 16364.5801
# Epoch 37/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11807.3926WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 15830.3301
# Epoch 38/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16997.0664WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 15805.8379
# Epoch 39/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 15942.6270WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 15492.3838
# Epoch 40/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18245.8906WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20468.4609
# Epoch 41/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20902.9961WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21185.0957
# Epoch 42/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17462.8945WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19952.6270
# Epoch 43/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 9852.3672WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19499.0859
# Epoch 44/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10156.1348WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 18760.1602
# Epoch 45/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10040.7129WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 18554.1895
# Epoch 46/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18870.6914WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 18667.9395
# Epoch 47/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20491.7148WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 18010.0605
# Epoch 48/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 7520.8569WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17317.0840
# Epoch 49/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 13932.1309WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 16954.7812
# Epoch 50/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20628.0391WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 18554.1172
# Epoch 51/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 13520.4209WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 17377.8867
# Epoch 52/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 7589.9692WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 17390.9961
# Epoch 53/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10880.2598WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 16474.7246
# Epoch 54/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12898.8105WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 16160.5664
# Epoch 55/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 19095.8984WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 15852.0273
# Epoch 56/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 34064.9805WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 15237.6152
# Epoch 57/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10115.5469WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 15075.3066
# Epoch 58/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 29374.6562WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 14715.7002
# Epoch 59/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10140.4600WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 14586.4629
# Epoch 60/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 8733.3379WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 14783.9404
# Epoch 61/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12281.6367WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 14105.0947
# Epoch 62/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 7791.3091WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 13431.9580
# Epoch 63/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 9972.8711WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 13761.7324
# Epoch 64/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 7879.0137WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 14638.5059
# Epoch 65/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17670.9766WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17486.4336
# Epoch 66/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21856.1016WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17236.5371
# Epoch 67/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 14267.9961WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 18733.2520
# Epoch 68/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10911.9404WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 17909.2148
# Epoch 69/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11204.0547WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17539.9648
# Epoch 70/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12985.0928WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17587.9512
# Epoch 71/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22673.0918WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 17994.8770
# Epoch 72/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20013.9297WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 16671.3262
# Epoch 73/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11087.7139WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 16349.2754
# Epoch 74/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 26811.8828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 15740.3154
# Epoch 75/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21003.9961WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19123.3281
# Epoch 76/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21311.9297WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 20620.3203
# Epoch 77/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 15889.5078WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20483.8789
# Epoch 78/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 31775.6719WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21822.6562
# Epoch 79/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21051.1680WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21912.6777
# Epoch 80/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20009.8359WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 21163.2617
# Epoch 81/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16078.8154WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21571.5645
# Epoch 82/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17236.5781WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 23167.1719
# Epoch 83/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12776.6143WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22728.7812
# Epoch 84/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12744.5342WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 23020.7148
# Epoch 85/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20267.4688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23057.7617
# Epoch 86/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20503.4023WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22911.4102
# Epoch 87/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18756.8711WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22941.2500
# Epoch 88/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17736.2676WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22693.5801
# Epoch 89/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22972.6836WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 22225.3008
# Epoch 90/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21328.6172WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21995.2188
# Epoch 91/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 35190.0664WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21806.4336
# Epoch 92/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 24691.0703WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21441.1621
# Epoch 93/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10876.3691WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21250.9492
# Epoch 94/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11627.2012WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21182.0312
# Epoch 95/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17763.7656WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21080.9453
# Epoch 96/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 14534.0635WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20917.2578
# Epoch 97/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 14623.7832WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20661.4199
# Epoch 98/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 26209.3945WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20958.9551
# Epoch 99/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 26856.1309WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20986.1074
# Epoch 100/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 24096.1406WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21054.5000
# Epoch 101/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16871.7148WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21073.5410
# Epoch 102/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 25955.3496WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21134.7812
# Epoch 103/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16087.2393WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21198.4648
# Epoch 104/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11823.9795WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21105.5645
# Epoch 105/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 24713.9395WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20878.0469
# Epoch 106/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21853.4863WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20681.0586
# Epoch 107/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22214.2422WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20452.0254
# Epoch 108/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 10743.7363WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20659.3730
# Epoch 109/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12645.7520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20804.7812
# Epoch 110/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 28214.8027WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20874.3203
# Epoch 111/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22935.9238WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 20649.0137
# Epoch 112/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 23169.3516WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20340.8613
# Epoch 113/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17202.6523WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20026.1445
# Epoch 114/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20382.4102WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19797.4023
# Epoch 115/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 28409.8594WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22411.1699
# Epoch 116/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 96255.6484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 35272.4570
# Epoch 117/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 26498.7148WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21717.8242
# Epoch 118/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12358.2734WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22044.1270
# Epoch 119/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 15990.7637WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21996.9688
# Epoch 120/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 34996.6016WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21785.0020
# Epoch 121/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17952.5820WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21694.1113
# Epoch 122/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 34771.4219WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21624.0176
# Epoch 123/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11472.6924WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21495.5840
# Epoch 124/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20060.2305WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21242.4980
# Epoch 125/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 25160.7969WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21104.1074
# Epoch 126/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 24534.6133WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20804.6816
# Epoch 127/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17441.2734WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20652.0078
# Epoch 128/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 8631.2627WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20457.3008
# Epoch 129/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 13833.3926WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20428.3457
# Epoch 130/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17174.6035WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20087.3809
# Epoch 131/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16573.0742WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19823.0254
# Epoch 132/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 23661.0254WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19682.3008
# Epoch 133/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 14042.2529WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19533.1934
# Epoch 134/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 14815.1836WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19163.6465
# Epoch 135/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21536.0625WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 20265.5645
# Epoch 136/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 23055.9727WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20353.1992
# Epoch 137/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 19663.1836WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20668.8340
# Epoch 138/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 23241.8574WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20719.5938
# Epoch 139/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 13131.7627WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19803.8477
# Epoch 140/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 28650.2656WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19950.3418
# Epoch 141/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18318.8691WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20014.3867
# Epoch 142/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21037.6484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19495.6289
# Epoch 143/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16062.2363WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19925.4648
# Epoch 144/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 7028.7729WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20139.5898
# Epoch 145/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12411.9160WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 20274.8203
# Epoch 146/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21251.2559WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19862.1348
# Epoch 147/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21995.3457WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21109.2520
# Epoch 148/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 14358.6406WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21063.8184
# Epoch 149/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 24152.9395WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21562.7715
# Epoch 150/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16094.3359WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22356.4941
# Epoch 151/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18857.1230WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 24234.7480
# Epoch 152/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 35799.8281WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 26162.2480
# Epoch 153/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 23852.1406WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 25819.5410
# Epoch 154/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 29457.3613WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 24719.2422
# Epoch 155/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 32632.9297WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23668.6797
# Epoch 156/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 34678.1953WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 24183.8203
# Epoch 157/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 15143.0137WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 24563.9219
# Epoch 158/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 41874.3984WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 25251.9668
# Epoch 159/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 37540.1094WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 25031.4141
# Epoch 160/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 31854.1680WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 24404.1602
# Epoch 161/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 28852.7422WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 24055.0020
# Epoch 162/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22057.9922WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23266.3535
# Epoch 163/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 26567.3594WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23458.1602
# Epoch 164/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21705.6465WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22955.6465
# Epoch 165/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 15489.0684WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22273.3047
# Epoch 166/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11196.1484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21965.0312
# Epoch 167/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18888.8203WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21834.3730
# Epoch 168/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 28589.9609WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22737.8398
# Epoch 169/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 34702.7852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 27955.5605
# Epoch 170/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 39727.8242WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 43254.7656
# Epoch 171/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 40912.0547WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 51628.2109
# Epoch 172/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 75917.0938WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 46309.3477
# Epoch 173/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 38199.7891WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 26466.3145
# Epoch 174/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21829.0098WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 24781.9590
# Epoch 175/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 15418.3955WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22492.4551
# Epoch 176/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 26458.0703WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 31791.8555
# Epoch 177/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 15515.2520WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 27476.7578
# Epoch 178/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 25565.1016WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 26049.6914
# Epoch 179/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 36688.0273WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# ...
# 6/6 [==============================] - 0s 4ms/step - loss: 20819.3496
# Epoch 1942/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 19477.4336WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20782.2832
# Epoch 1943/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 13719.3770WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20948.0547
# Epoch 1944/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 35183.5156WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20824.1621
# Epoch 1945/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12088.4121WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21031.3164
# Epoch 1946/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11146.2256WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22226.5703
# Epoch 1947/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 29382.7969WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23953.9199
# Epoch 1948/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11770.4043WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 25678.5586
# Epoch 1949/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 14726.6816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21558.0078
# Epoch 1950/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 35318.6484WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20958.3574
# Epoch 1951/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 37047.2852WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20243.0977
# Epoch 1952/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12107.9336WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21066.5020
# Epoch 1953/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 33800.4219WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22202.2949
# Epoch 1954/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 36218.5938WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 20690.0312
# Epoch 1955/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22371.0195WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20495.1016
# Epoch 1956/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 19029.9824WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21722.1895
# Epoch 1957/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11604.7334WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21597.8438
# Epoch 1958/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 19851.3145WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23848.1465
# Epoch 1959/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 30575.5898WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21372.2637
# Epoch 1960/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22437.5215WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20676.7891
# Epoch 1961/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 24378.3828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 25501.2812
# Epoch 1962/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 19911.1953WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 27211.7285
# Epoch 1963/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18727.4219WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22800.0508
# Epoch 1964/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 28780.1074WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20785.3262
# Epoch 1965/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16618.6523WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20483.9121
# Epoch 1966/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 11991.3545WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22759.3398
# Epoch 1967/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18039.8906WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20585.3887
# Epoch 1968/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16434.5117WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20004.5312
# Epoch 1969/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 13328.8652WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20549.3418
# Epoch 1970/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 27813.5664WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20161.8691
# Epoch 1971/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 25428.0352WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20391.6699
# Epoch 1972/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 20076.7031WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20448.2441
# Epoch 1973/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 7009.4150WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20390.0078
# Epoch 1974/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22905.7031WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21193.5312
# Epoch 1975/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17911.9688WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20656.7676
# Epoch 1976/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 13876.1387WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20254.5605
# Epoch 1977/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 17726.1602WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20298.0547
# Epoch 1978/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 25539.3398WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20368.9766
# Epoch 1979/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18932.3535WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20142.4316
# Epoch 1980/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16991.4746WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 19994.7715
# Epoch 1981/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 33338.0938WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20390.1562
# Epoch 1982/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 7513.2739WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20655.7324
# Epoch 1983/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 18404.8828WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21481.7148
# Epoch 1984/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 7751.8237WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 23501.1855
# Epoch 1985/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 14839.1846WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 22930.9062
# Epoch 1986/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 23310.2227WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22260.8418
# Epoch 1987/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 12566.8477WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20784.3281
# Epoch 1988/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 28921.6328WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21042.8887
# Epoch 1989/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 13572.4746WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 22089.0801
# Epoch 1990/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 8420.4980WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20433.1699
# Epoch 1991/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 16586.1875WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20669.3770
# Epoch 1992/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 34131.7812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21071.8457
# Epoch 1993/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 21836.1367WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20366.0293
# Epoch 1994/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 29902.5156WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 19838.1445
# Epoch 1995/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 30132.2832WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20117.4941
# Epoch 1996/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 22643.1172WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 19921.9492
# Epoch 1997/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 27073.8145WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 3ms/step - loss: 21468.0078
# Epoch 1998/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 30072.0605WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20030.7852
# Epoch 1999/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 25981.7676WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 20977.6621
# Epoch 2000/2000
# 1/6 [====>.........................] - ETA: 0s - loss: 8207.4180WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss
# 6/6 [==============================] - 0s 4ms/step - loss: 21410.2168

# %%
#이렇게 나눠놓으니 위에 학습한것을 토대로 계속 학습하면 시간 안걸리고 다음숫자 예측할수있다.

# 예측을 위한 새로운 데이터 포인트
x_input = np.array([36, 20, 365, 146, 20, 22, 163, 120, 23, 1, 20, 129, 97, 297, 224, 172,105, 93, 238, 143])
x_input = x_input.reshape((1, n_steps, 1))

# 다음 숫자 예측
yhat = model.predict(x_input, verbose=1) # verbose 설정에따라 학습상황을 아려줍니다.
yhat[0][0]  # 예측된 다음 숫자 출력
# Out:
# 1/1 [==============================] - 0s 10ms/step
# 99.281204

# %% [markdown]
# # LSTM 숫자 우연인지 몇번 정확히 맞췃다.
# 데이터 세트의 크기를 키우며 어디서 맞추는지 실험해본다. 1.스텝의 크기 2.데이터세트의 크기 조절해볼것 세트 크기 (1000개:120예측 10000:90예측 2000:112예측) 1000개에서 더 근사하게 맞춘다.
# 손좀봐보자
# 정확히 맞춘것은 데이터세트 1000개 숫자배열 크기가 8일때였다
# ###같은 조건으로 반복하여도 예측숫자는 다르게 출력된다.
# ### 계속해보니  확률적으로 근사하여서 맞추는것같긴하다
# 우연이 아니었다 1000개 8개일때 적중하는 숫자있다. 어느정도 맞추는것같다 모델 조금더 손보자 그리고 (나중에 내가 모델 만들어보기도 하자)
# for문으로 5번정도 시켜서 숫자보기
# 실험 (159 130 170 109 128)

# %% [markdown]
# # LSTM 두번째 모델

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense

# 모델 정의
n_steps = 5  # 입력 시퀀스의 길이
n_features = 1  # 특징의 개수

model = Sequential([
    LSTM(50, activation='relu', input_shape=(n_steps, n_features)),
    Dense(2)  # 두 개의 출력: 예측값과 불확실성
])

# 모델 컴파일
model.compile(optimizer='adam', loss='mean_squared_error')

# 예측을 위한 새로운 데이터 포인트
x_input = np.array([23, 1, 20, 129, 97])
x_input = x_input.reshape((1, n_steps, 1))

# 예측
yhat = model.predict(x_input, verbose=0)  # verbose=0으로 설정하여 학습 상황 출력 없음
prediction, uncertainty = yhat[0][0], yhat[0][1]  # 예측된 다음 숫자와 불확실성 출력

print(f"예측된 값: {prediction}, 불확실성: {uncertainty}")
#불확실성은 낮을수록 좋다.(0에 가까울수록)
# Out:
# 예측된 값: -17.43350601196289, 불확실성: -4.0912675857543945

# %% [markdown]
# - 램덤에 대한 예측을 시도해보았다. 완전한 램덤은 아니지만 램덤시행에서 파생되었기때문에 유사램덤이긴 하다. 우선 스텝의 크기 데이터의 크기 얼리스탑핑 페이션트 크기 등 여러가지를 조절해봒는데 랜덤을 학습하기에는 맞지않고 랜덤은 학습이 불가능한데 유사랜덤이라 매우 학습하기 어려웠던것같다.
