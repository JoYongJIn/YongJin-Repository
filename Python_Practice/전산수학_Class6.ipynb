# %% [markdown]
# <a href="https://colab.research.google.com/github/JoYongJIn/YongJin-Repository/blob/main/%EC%A0%84%EC%82%B0%EC%88%98%ED%95%99_Class6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
'''
 ====================================
 반복문: for 문
 ====================================
 '''
 #========================
 # for 문 + list
 #========================
test_list = ['a','b','c']
for i in test_list:
     print(i)

test_list2 = [1,3,5, 7,9]
for i in test_list2:
     print(i)

a = [(1,2), (3,4), (5,6)]#리스트안에 튜플
for (first, last) in a:
     print(first+last)

 # Exercise: ======================
 #(1) 100이상의 숫자만 프린트
numbers = [123, 104, 4, 17, 87, 800, 99]
for i in numbers:
  if i>=100:
    print(i)

 #(2) 100이상의 숫자가 몇개인지?
numbers = [123, 104, 4, 17, 87, 800, 99]
count=0
for i in numbers:
  if i>=100:
    print(i)
    count=count+1
print('100이상의 숫자는 %d개이다'%count)


 #(3) 각요소가 몇자리 숫자인지 출력:***은*자리수입니다.
numbers = [123, 104, 4, 17, 87, 800, 99]
for i in numbers:
   print(i,'는',len(str(i)),'자리수입니다')
   print('%d는 %d 자릿수입니다' %(i,len(str(i))))

 #================================

 # 예제 1
 # 출력결과: *번 학생은 (불)합격입니다.
marks = [90, 25, 67, 45, 80]
num = 0
for i in marks:
  num=num+1
  if i>=60:
    print('%d번째 학생은 합격입니다'%num)
  else:
    print('%d번째 학생은 불합격입니다'%num)
 # 출력결과: *번 학생은 (불)합격입니다.


# 예제 2
# 출력결과: *번 학생 축하합니다. 합격입니다.
marks = [90, 25, 67, 45, 80]
num = 0
for i in marks:
  num=num+1
  if i>=60: continue
  print('%d 번 학생은')

 # 출력결과: *번 학생 축하합니다. 합격입니다.


 #========================
 # for 문 + dictionary
 #========================

 # 예제
numbers = [1, 2, 6, 8, 4, 3, 2, 1, 9, 5 ,4, 9, 7, 4, 8,9,7,2,3]
counter={} #새로운 딕셔너리 생성

for i in numbers:
    if i in counter:
      counter[i]=counter[i]+1
    else:
      counter[i]=1

print(counter)
 # 출력결과: {1: 2, 2: 3, 6: 1, 8: 2, 4: 3, 3: 2, 9: 3, 5: 1, 7: 2}

#예제
counter={}
score = [70,83,92,65,54,75,80,90]
counter['A']=0; counter['B']=0; counter['C']=0
for i in score:
  if i>=80:
    counter['A']=counter['A']+1
  elif 70<=i<80:
    counter['B']=counter['B']+1
  else:
    counter['C']=counter['C']+1

print(counter)

#예제
a=0
while
for i in range(1000)

 #====================================
 # range + for 문
 #====================================
 a= range(10) # 0,1,2,...,9
 a=range(1,11) # 1,2,...,10
 a=range(1,11, 2) # 1,3,5,7,9

 # 예제
 for i in range(11):#아래로 내려가며 출력된다
     print(i)

 for i in reversed(range(11)):
     print(i)

 # 예제: 숫자더하기
total=0
for i in range(1,11):
  total +=i
print(total)

a=range(1,11)
b=list(a)
print(b)

total=0
for i in range(1,11):
  total +=i
a=range(1,11)
a[0]
a[-1]
print('%d부터 %d까지의 합은 %d이다'%(a[0],a[-1],total))
 # 앞의 예제
marks = [90, 25, 67, 45, 80]
num = 0
for i in marks:
  num=num+1
  if i<60:
    continue
    print('yes')
  print('%d 번 학생은 합격입니다.'%num)

marks = [90, 25, 67, 45, 80]
num = 0
for i in marks:
  num=num+1
  if i<60:
    pass
    print('yes')
  print('%d 번 학생은 합격입니다.'%num)

marks=[90,25,67,45,80]
for i in range(len(marks)):
  score=marks[i]
  if score<60:
    continue
  print('%d 번 학생은 합격입니다.'%(i+1))


for i in range(2,5):
  for j in range(1,5):
    print(i*j, end=' ')
 # 예제:  한줄에 결괏값 출력



 # 예제: 구구단 출력하기
for k in range(2,10):
     for j in range(1, 10):
         print('%d X %d = %d' %(k, j, k*j))

line = ''
for k in range(2,10):
     line = line + str('#   %d단   # '%k)
 print(line)

for j in range(1,10):
  line = ''
  for k in range(2,10):
    line = line + str('%d x %d = %2d  '%(k,j,k*j))
    print(line)


# 예제: dictionary (for loop 이용해서)
Keys = ['name', 'hp', 'mp', 'level']
values = ['기사', 200, 30, 5]
character = {} # dictionary

for i in range(len(Keys)):
  character[Keys[i]]=values[i]

print(character)
#출력결과: {'name': '기사', 'hp': 200, 'mp':30, 'level':5)


#연습문제:
#1*99, 2*98, 3*97, ... 99*1 중에서 최대가 되는 경우는 어떤 두 숫자를 곱했을 떄인지를 찾는 코드를 for문 이용해서 작성하기

maxvalue = 0  # 초기화
for a in range(1, 200):
    b = 200 - a
    m = a * b
    if m > maxvalue:
        maxvalue = m
        max_a = a  # 최댓값일 때의 a, b 값 저장
        max_b = b
print('%d X %d = %d 가 최댓값이다' % (max_a, max_b, maxvalue))
#=========================================
for i in range(1,100//2+1):
  j = 100-i
  k= j*i
  maxvalue = k
  if k>maxvalue:
      maxvalue=k

print("곱하였을때 최대가 되는 경우는 %d"%k)
#=========제출용========================
for i in range(1,100//2+1):
  j = 100-i
  k= j*i
  maxvalue = k
  if maxvalue>maxvalue:
      maxvalue=k

print("곱하였을때 최대가 되는 경우는 %d"%k)
 #=====================================
 # 리스트 내포 사용하기
 #=====================================
a = [1,2,3,4]
result = [];
for num in a:
     result.append(num*3)
print(result) #[3, 6, 9, 12]

 # 리스트 내포(list comprehension)
results2 = [num*3 for num in a]
print(results2) #[3, 6, 9, 12]

results3 = [num*3 for num in a if num%2==0]
print(results3) #[6, 12]

results4 = [i*j for i in range(2,10) for j in range(1,10)]
print(results4)

print(i*j)
 ## Exercise=================================================

 #1. 10명의 학생들의 중간고사 점수는 [70, 60,55,75, 95,90,80,80,85,100]이다.
#for문을 사용하여 A학급의 평균 점수를 구하고, 90점이 넘는 학생수를 구하여라
total=0
a=[70, 60,55,75, 95,90,80,80,85,100]
for i in a:
  total+=i

t=total/len(a)

print(t)

count=0
for i in a:
    if i>90:
        count+=1

print(count)

print('A학급의 평균은 %.2f이고, 90점이 넘는 학생수는 %d이다.'%(t,count))

#교수님코딩
total=0
count=0
for i in range(len(score)):
   total += score[i]
   if score[i]>90:
     count+=1
print('평균은 '%(total/len(score),count))

A=[num*2 for num in B if num%2==1]
print(A)

#2. [1,2,3,4,5,6,7] 리스트중에서 홀수에만 2를 곱하여 저장하는 코드를 '리스트 내포'를 사용하여 만들어라
a=[1,2,3,4,5,6,7]
b=[i*2 for i in a if i%2==1]
print(b)


a=[1,2,3,4,5,6,7]
b=[i*2 for i in a if i%2==1]
print(b)
 #3.

 #4.

# %%
for i in range(1,100//2+1):
  j = 100-i
  k= j*i
  maxvalue = k
  if maxvalue>maxvalue:
      maxvalue=k
      a= i;b=j

print("%d과 %d 곱하였을때 최대가 되는 경우는 %d"%(i,j,k))

# %%
num=0
sum=0
for i in range(1,1000):
  if i%3==0 or i%5==0:
    num+=1
    sum+=i

print('3의 배수 또는 5의 배수의 개수는 {}이며, 그 총합은 {}이다.'.format(num,sum))
# Out:
# 3의 배수 또는 5의 배수의 개수는 466이며, 그 총합은 233168이다.

# %%
i=1
num=0; sum=0
while i<1000:
  if i%3==0 or i%5==0:
    num+=1
    sum+=i
  i=i+1

print('3의 배수 또는 5의 배수의 개수는 {}이며, 그 총합은 {}이다.'.format(num,sum))
# Out:
# 3의 배수 또는 5의 배수의 개수는 466이며, 그 총합은 233168이다.
